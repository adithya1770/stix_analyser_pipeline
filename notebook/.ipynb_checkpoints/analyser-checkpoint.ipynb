# %%
# !pip install networkx
# !pip install stix2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: networkx in /home/adithya/.local/lib/python3.10/site-packages (3.4.2)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting stix2
#   Downloading stix2-3.0.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from stix2) (2022.1)
# Requirement already satisfied: requests in /home/adithya/.local/lib/python3.10/site-packages (from stix2) (2.32.5)
# Collecting simplejson (from stix2)
#   Downloading simplejson-3.20.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting stix2-patterns>=2.1.2 (from stix2)
#   Downloading stix2_patterns-2.1.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting antlr4-python3-runtime~=4.13.0 (from stix2-patterns>=2.1.2->stix2)
#   Downloading antlr4_python3_runtime-4.13.2-py3-none-any.whl.metadata (304 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/adithya/.local/lib/python3.10/site-packages (from requests->stix2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->stix2) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->stix2) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->stix2) (2020.6.20)
# Downloading stix2-3.0.2-py2.py3-none-any.whl (161 kB)
# Downloading stix2_patterns-2.1.2-py2.py3-none-any.whl (81 kB)
# Downloading antlr4_python3_runtime-4.13.2-py3-none-any.whl (144 kB)
# Downloading simplejson-3.20.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# Installing collected packages: antlr4-python3-runtime, stix2-patterns, simplejson, stix2
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [stix2]━━━━━ 3/4 [stix2]
# Successfully installed antlr4-python3-runtime-4.13.2 simplejson-3.20.2 stix2-3.0.2 stix2-patterns-2.1.2

# %%
import json

with open("../data/stix20/enterprise-attack.json") as file:
    data = json.load(file)

print(data["objects"][0].keys(), "\n")
print(data.keys())
count = 0
for obj in data["objects"]:
    if obj.get("type") == "relationship":
        count += 1
print("Number of relationship objects:", count)
# Out:
# dict_keys(['type', 'id', 'created', 'created_by_ref', 'external_references', 'object_marking_refs', 'modified', 'name', 'description', 'tactic_refs', 'x_mitre_modified_by_ref', 'x_mitre_deprecated', 'x_mitre_domains', 'x_mitre_version', 'x_mitre_attack_spec_version'])
#
# dict_keys(['type', 'id', 'objects', 'spec_version'])
# Number of relationship objects: 20048

# %%
types = set()

for obj in data["objects"]:
    types.add(obj["type"])

print(types)
print("Total types:", len(types))
# Out:
# {'x-mitre-data-component', 'identity', 'campaign', 'x-mitre-analytic', 'marking-definition', 'x-mitre-matrix', 'course-of-action', 'intrusion-set', 'tool', 'attack-pattern', 'x-mitre-tactic', 'relationship', 'x-mitre-data-source', 'x-mitre-detection-strategy', 'malware'}
# Total types: 15

# %%
nodes = []
relationships = []

for obj in data["objects"]:
    if obj["type"] == "relationship":
        relationships.append(obj)
    else:
        nodes.append(obj)

print("Number of nodes:", len(nodes))
print("Number of relationships:", len(relationships))
# Out:
# Number of nodes: 4723
# Number of relationships: 20048

# %%
import networkx as nx

G = nx.DiGraph()

for node in nodes:
    node_id = node["id"]
    node_type = node["type"]
    G.add_node(node_id, type=node_type)

for rel in relationships:
    src = rel["source_ref"]
    tgt = rel["target_ref"]
    rel_type = rel["relationship_type"]

    G.add_edge(src, tgt, relationship=rel_type)

print("Graph built.")
print("Total graph nodes:", G.number_of_nodes())
print("Total graph edges:", G.number_of_edges())
# Out:
# Graph built.
# Total graph nodes: 4723
# Total graph edges: 20048
